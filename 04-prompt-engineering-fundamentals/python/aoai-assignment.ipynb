# %% [markdown]
# The following notebook was auto-generated by GitHub Copilot Chat and is meant for initial setup only

# %% [markdown]
# # Introduction to Prompt Engineering
# A engenharia de prompts é o processo de projetar e otimizar prompts para tarefas de processamento de linguagem natural. Envolve selecionar os prompts adequados, ajustar seus parâmetros e avaliar seu desempenho. A engenharia de prompts é crucial para alcançar alta precisão e eficiência em modelos de PLN. Nesta seção, exploraremos os fundamentos da engenharia de prompts usando os modelos da OpenAI como exemplo.

# %% [markdown]
# ### Exercise 1: Tokenization
# Explore Tokenization using tiktoken, an open-source fast tokenizer from OpenAI
# See [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) for more examples.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### Exercise 2: Validate OpenAI API Key Setup
#
# Run the code below to verify that your OpenAI endpoint is set up correctly. The code just tries a simple basic prompt and validates the completion. Input `oh say can you see` should complete along the lines of `by the dawn's early light..`

# %%
# The OpenAI SDK was updated on Nov 8, 2023 with new guidance for migration
# See: https://github.com/openai/openai-python/discussions/742

## Updated
import os
from openai import AzureOpenAI
from dotenv import load_dotenv
load_dotenv()

client = AzureOpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],  # this is also the default, it can be omitted
  api_version = "2023-05-15"
  )

#deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']
deployment='gpt-4.1-nano'

## Updated
def get_completion(prompt):
    messages = [{"role": "user", "content": prompt}]       
    response = client.chat.completions.create(   
        model=deployment,                                         
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
        max_tokens=1024
    )
    return response.choices[0].message.content

# %%
## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# The phrase "Oh say can you see" is the opening line of the United States national anthem, "The Star-Spangled Banner." Would you like more information about the song or its history?

# %% [markdown]
# ### Exercise 3: Fabrications
# Explore o que acontece quando você pede ao LLM para retornar sugestões para um tópico que pode não existir ou sobre tópicos que ele pode desconhecer por estarem fora de seu conjunto de dados pré-treinado (mais recentes). Veja como a resposta muda se você tentar um tópico diferente ou um modelo diferente.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)
# Out:
# **Lesson Plan: The Martian War of 2076**
#
# **Grade Level:** 9-12
# **Subject:** History / Science Fiction Literature / Social Studies
# **Duration:** 1 hour
#
# ---
#
# ### **Lesson Objectives:**
# - Understand the fictional events of the Martian War of 2076.
# - Analyze the social, political, and technological implications depicted in the story.
# - Explore themes of human resilience, interplanetary conflict, and technological advancement.
# - Encourage critical thinking about the portrayal of future warfare and its relevance to current global issues.
#
# ---
#
# ### **Materials Needed:**
# - Excerpts or summaries of "The Martian War of 2076" (from H.G. Wells' "The War of the Worlds" or related adaptations)
# - Visual aids (maps of Mars and Earth, timeline graphics)
# - Whiteboard and markers
# - Student notebooks or digital devices for note-taking
# - Handouts with discussion questions
#
# ---
#
# ### **Lesson Procedure:**
#
# #### **Introduction (10 minutes)**
# ...

# %% [markdown]
# ### Exercise 4: Instruction Based
# Use a variável "texto" para definir o conteúdo principal e a variável "instrução" para fornecer uma instrução relacionada a esse conteúdo principal.
#
# Aqui, pedimos ao modelo que resuma o texto para um aluno do segundo ano.

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# Jupiter is a big planet far away from the Sun. It is the fifth planet from the Sun and the biggest one in space. Jupiter is made of gas and is very heavy—more than all the other planets put together. It is very bright and can be seen in the night sky. People have known about Jupiter for a very long time, even before there were books. It is named after a Roman god called Jupiter. Sometimes, Jupiter is so bright that it can cast shadows on Earth!

# %% [markdown]
# ### Exercise 5: Complex Prompt
# Experimente uma solicitação que inclua mensagens do sistema, do usuário e do assistente.
# O sistema define o contexto do assistente.
# As mensagens do usuário e do assistente fornecem o contexto da conversa em várias etapas.
#
# Observe como a personalidade do assistente está definida como "sarcástica" no contexto do sistema.
#
# Tente usar um contexto de personalidade diferente. Ou tente uma sequência diferente de mensagens de entrada/saída.

# %%
response = client.chat.completions.create(
    model=deployment,
    messages=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ]
)
print(response.choices[0].message.content)
# Out:
# Oh, it was held at Globe Life Field in Arlington, Texas. Because nothing screams "world series" like a neutral site during a pandemic.

# %% [markdown]
# ### Exercise: Explore Your Intuition
# Os exemplos acima fornecem padrões que você pode usar para criar novos prompts (simples, complexos, instruções etc.) - tente criar outros exercícios para explorar algumas das outras ideias que discutimos, como exemplos, dicas e muito mais.
